# %%
from sqlalchemy import create_engine
from sqlalchemy import inspect
import pandas as pd

# %%
engine = create_engine("sqlite:///mta_data.db")

# %%
insp = inspect(engine)
print(insp.get_table_names())
# Out:
# ['mta_data']

# %% [markdown]
# # Moving Data to Pandas for Cleaning and Analysis

# %%
# Choose not pull in DIVISION as that column not needed for analysis
# Did not pull in 2020 dates, only using 2021 data

df_mta = pd.read_sql("""SELECT "C/A", UNIT, SCP, STATION, LINENAME, DATE, TIME, DESC, ENTRIES, EXITS 
                        FROM mta_data WHERE DATE NOT LIKE "%2020"
                        ORDER BY STATION, UNIT, SCP, DATE, TIME;""", engine )

# %%
df_mta.shape
# Out:
# (7355276, 10)

# %%
df_mta.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME        DATE      TIME     DESC  \
# 0  H007  R248  00-00-00    1 AV        L  01/01/2021  03:00:00  REGULAR
# 1  H007  R248  00-00-00    1 AV        L  01/01/2021  07:00:00  REGULAR
# 2  H007  R248  00-00-00    1 AV        L  01/01/2021  11:00:00  REGULAR
# 3  H007  R248  00-00-00    1 AV        L  01/01/2021  15:00:00  REGULAR
# 4  H007  R248  00-00-00    1 AV        L  01/01/2021  19:00:00  REGULAR
#
#     ENTRIES     EXITS
# 0  15512487  17566757
# 1  15512489  17566802
# 2  15512503  17566903
# 3  15512538  17567059
# 4  15512578  17567190

# %%
df_mta.tail()
# Out:
#           C/A  UNIT       SCP    STATION LINENAME        DATE      TIME  \
# 7355271  R419  R326  00-05-01  ZEREGA AV        6  09/03/2021  05:00:00
# 7355272  R419  R326  00-05-01  ZEREGA AV        6  09/03/2021  09:00:00
# 7355273  R419  R326  00-05-01  ZEREGA AV        6  09/03/2021  13:00:00
# 7355274  R419  R326  00-05-01  ZEREGA AV        6  09/03/2021  17:00:00
# 7355275  R419  R326  00-05-01  ZEREGA AV        6  09/03/2021  21:00:00
#
#             DESC  ENTRIES  EXITS
# 7355271  REGULAR       39    182
# 7355272  REGULAR       39    182
# 7355273  REGULAR       39    182
# 7355274  REGULAR       39    182
# 7355275  REGULAR       39    182

# %%
df_mta.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DATE', 'TIME', 'DESC',
#        'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
df_mta.columns = [column.strip() for column in df_mta.columns]
df_mta.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DATE', 'TIME', 'DESC',
#        'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
df_mta.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7355276 entries, 0 to 7355275
# Data columns (total 10 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   C/A       7355276 non-null  object
#  1   UNIT      7355276 non-null  object
#  2   SCP       7355276 non-null  object
#  3   STATION   7355276 non-null  object
#  4   LINENAME  7355276 non-null  object
#  5   DATE      7355276 non-null  object
#  6   TIME      7355276 non-null  object
#  7   DESC      7355276 non-null  object
#  8   ENTRIES   7355276 non-null  int64
#  9   EXITS     7355276 non-null  int64
# dtypes: int64(2), object(8)
# memory usage: 561.2+ MB

# %%
df_mta.describe()
# Out:
#             ENTRIES         EXITS
# count  7.355276e+06  7.355276e+06
# mean   4.192492e+07  3.363603e+07
# std    2.186116e+08  1.932745e+08
# min    0.000000e+00  0.000000e+00
# 25%    2.201160e+05  9.579900e+04
# 50%    1.449856e+06  8.736350e+05
# 75%    6.107855e+06  4.025998e+06
# max    2.147432e+09  2.133797e+09

# %%
# YTD Data 9/3/2021
df_mta.DATE.value_counts().sort_index()
# Out:
# 01/01/2021    30696
# 01/02/2021    30595
# 01/03/2021    29807
# 01/04/2021    29779
# 01/05/2021    29802
#               ...
# 08/30/2021    30738
# 08/31/2021    29865
# 09/01/2021    30159
# 09/02/2021    29664
# 09/03/2021    29534
# Name: DATE, Length: 246, dtype: int64

# %%
# Code from Nina
# pd.options.display.max_rows = 200
# df_mta.head(100)

# %%
# convert to time series
import datetime as dt

# %%
df_mta["DATE_TIME"] = pd.to_datetime(df_mta.DATE + " " + df_mta.TIME, 
                                            format="%m/%d/%Y %H:%M:%S")

# %%
df_mta.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME        DATE      TIME     DESC  \
# 0  H007  R248  00-00-00    1 AV        L  01/01/2021  03:00:00  REGULAR
# 1  H007  R248  00-00-00    1 AV        L  01/01/2021  07:00:00  REGULAR
# 2  H007  R248  00-00-00    1 AV        L  01/01/2021  11:00:00  REGULAR
# 3  H007  R248  00-00-00    1 AV        L  01/01/2021  15:00:00  REGULAR
# 4  H007  R248  00-00-00    1 AV        L  01/01/2021  19:00:00  REGULAR
#
#     ENTRIES     EXITS           DATE_TIME
# 0  15512487  17566757 2021-01-01 03:00:00
# 1  15512489  17566802 2021-01-01 07:00:00
# 2  15512503  17566903 2021-01-01 11:00:00
# 3  15512538  17567059 2021-01-01 15:00:00
# 4  15512578  17567190 2021-01-01 19:00:00

# %% [markdown]
# Duplicate Entries Diagnostic
#
# Isolate specific turnstiles by creating a boolean series mask and then use them to index into the dataframe
# A Mask acts like a filter

# %%
mask = ((df_mta["C/A"] == "H007") &
        (df_mta["UNIT"] == "R248") & 
        (df_mta["SCP"] == "00-00-00") & 
        (df_mta["STATION"] == "1 AV"))

df_mta[mask].head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME        DATE      TIME     DESC  \
# 0  H007  R248  00-00-00    1 AV        L  01/01/2021  03:00:00  REGULAR
# 1  H007  R248  00-00-00    1 AV        L  01/01/2021  07:00:00  REGULAR
# 2  H007  R248  00-00-00    1 AV        L  01/01/2021  11:00:00  REGULAR
# 3  H007  R248  00-00-00    1 AV        L  01/01/2021  15:00:00  REGULAR
# 4  H007  R248  00-00-00    1 AV        L  01/01/2021  19:00:00  REGULAR
#
#     ENTRIES     EXITS           DATE_TIME
# 0  15512487  17566757 2021-01-01 03:00:00
# 1  15512489  17566802 2021-01-01 07:00:00
# 2  15512503  17566903 2021-01-01 11:00:00
# 3  15512538  17567059 2021-01-01 15:00:00
# 4  15512578  17567190 2021-01-01 19:00:00

# %%
# Check to see if "C/A", "UNIT", "SCP", "STATION", "DATE_TIME" = Unique row of data for entries
duplicate_entries = (df_mta
 .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"])
 .ENTRIES.count()
 .reset_index()
 .sort_values("ENTRIES", ascending=False))

# %%
duplicate_entries.head()
# Out:
#           C/A  UNIT       SCP         STATION           DATE_TIME  ENTRIES
# 1996900  N071  R013  00-00-04  34 ST-PENN STA 2021-04-08 08:00:00        2
# 2353010  N114  R297  01-00-01     FRANKLIN AV 2021-03-10 08:00:00        2
# 1993942  N071  R013  00-00-02  34 ST-PENN STA 2021-04-08 08:00:00        2
# 2699899  N213  R154  00-00-00      TREMONT AV 2021-06-23 05:00:00        2
# 625683   B024  R211  00-05-00       KINGS HWY 2021-05-01 00:00:00        2

# %%
# On serveral days there are duplicate entries for the same time. Let's take a look at first one
import datetime
mask_1 = ((df_mta["C/A"] == "N071") & 
(df_mta["UNIT"] == "R013") & 
(df_mta["SCP"] == "00-00-04") & 
(df_mta["STATION"] == "34 ST-PENN STA") &
(df_mta["DATE_TIME"].dt.date == dt.datetime(2021, 4, 8).date()))

df_mta[mask_1].head(10)
# Out:
#           C/A  UNIT       SCP         STATION LINENAME        DATE      TIME  \
# 1347617  N071  R013  00-00-04  34 ST-PENN STA      ACE  04/08/2021  00:00:00
# 1347618  N071  R013  00-00-04  34 ST-PENN STA      ACE  04/08/2021  04:00:00
# 1347619  N071  R013  00-00-04  34 ST-PENN STA      ACE  04/08/2021  06:40:30
# 1347620  N071  R013  00-00-04  34 ST-PENN STA      ACE  04/08/2021  06:41:49
# 1347621  N071  R013  00-00-04  34 ST-PENN STA      ACE  04/08/2021  08:00:00
# 1347622  N071  R013  00-00-04  34 ST-PENN STA      ACE  04/08/2021  08:00:00
# 1347623  N071  R013  00-00-04  34 ST-PENN STA      ACE  04/08/2021  12:00:00
# 1347624  N071  R013  00-00-04  34 ST-PENN STA      ACE  04/08/2021  16:00:00
# 1347625  N071  R013  00-00-04  34 ST-PENN STA      ACE  04/08/2021  20:00:00
#
#                DESC   ENTRIES     EXITS           DATE_TIME
# 1347617     REGULAR   1871551     39764 2021-04-08 00:00:00
# 1347618     REGULAR   1871552     39768 2021-04-08 04:00:00
# 1347619     REGULAR  11289337  10471686 2021-04-08 06:40:30
# 1347620     REGULAR  11289337  10471689 2021-04-08 06:41:49
# 1347621     REGULAR  11289423  10471731 2021-04-08 08:00:00
# 1347622  RECOVR AUD   1871567     39821 2021-04-08 08:00:00
# 1347623  RECOVR AUD   1871647     39885 2021-04-08 12:00:00
# 1347624     REGULAR   1871826     39928 2021-04-08 16:00:00
# 1347625     REGULAR   1872033     39967 2021-04-08 20:00:00

# %% [markdown]
# - Three entries for 4/8/2021 look to be out of sequence with abnormally high values

# %%
df_mta.DESC.value_counts()
# Out:
# REGULAR       7324247
# RECOVR AUD      31029
# Name: DESC, dtype: int64

# %%
# Get rid of the duplicate entry duplicates equate to .004% of data ok to delete one aritrarily
# The amount of duplicate rows deleted won't affect the analysis even if the inaccurate one is selected for deletion
df_mta.sort_values(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"], 
                          inplace=True, ascending=False)
df_mta.drop_duplicates(subset=["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"], inplace=True)

# %%
# Sanity Check to verify that "C/A", "UNIT", "SCP", "STATION", "DATE_TIME" is unique based on Time of Entry
(df_mta
 .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"])
 .ENTRIES.count()
 .reset_index()
 .sort_values("ENTRIES", ascending=False)).head(5)
# Out:
#           C/A  UNIT       SCP         STATION           DATE_TIME  ENTRIES
# 0        A002  R051  02-00-00           59 ST 2021-01-01 03:00:00        1
# 4903556  R138  R293  00-05-00  34 ST-PENN STA 2021-02-05 05:00:00        1
# 4903414  R138  R293  00-05-00  34 ST-PENN STA 2021-01-12 13:00:00        1
# 4903413  R138  R293  00-05-00  34 ST-PENN STA 2021-01-12 09:00:00        1
# 4903412  R138  R293  00-05-00  34 ST-PENN STA 2021-01-12 05:00:00        1

# %%
# A wide range of times were used to collect data
df_mta.TIME.value_counts()
# Out:
# 04:00:00    580406
# 08:00:00    580370
# 12:00:00    580326
# 16:00:00    580315
# 20:00:00    580175
#              ...
# 06:24:47         1
# 10:36:47         1
# 09:33:20         1
# 14:48:47         1
# 01:21:31         1
# Name: TIME, Length: 80214, dtype: int64

# %%
mask_1 = ((df_mta["C/A"] == "N071") & 
(df_mta["UNIT"] == "R013") & 
(df_mta["SCP"] == "00-00-04") & 
(df_mta["STATION"] == "34 ST-PENN STA") &
(df_mta["DATE_TIME"].dt.date == dt.datetime(2021, 4, 8).date()))

df_mta[mask_1].head(10)
# Out:
#           C/A  UNIT       SCP         STATION LINENAME        DATE      TIME  \
# 1347625  N071  R013  00-00-04  34 ST-PENN STA      ACE  04/08/2021  20:00:00
# 1347624  N071  R013  00-00-04  34 ST-PENN STA      ACE  04/08/2021  16:00:00
# 1347623  N071  R013  00-00-04  34 ST-PENN STA      ACE  04/08/2021  12:00:00
# 1347621  N071  R013  00-00-04  34 ST-PENN STA      ACE  04/08/2021  08:00:00
# 1347620  N071  R013  00-00-04  34 ST-PENN STA      ACE  04/08/2021  06:41:49
# 1347619  N071  R013  00-00-04  34 ST-PENN STA      ACE  04/08/2021  06:40:30
# 1347618  N071  R013  00-00-04  34 ST-PENN STA      ACE  04/08/2021  04:00:00
# 1347617  N071  R013  00-00-04  34 ST-PENN STA      ACE  04/08/2021  00:00:00
#
#                DESC   ENTRIES     EXITS           DATE_TIME
# 1347625     REGULAR   1872033     39967 2021-04-08 20:00:00
# 1347624     REGULAR   1871826     39928 2021-04-08 16:00:00
# 1347623  RECOVR AUD   1871647     39885 2021-04-08 12:00:00
# 1347621     REGULAR  11289423  10471731 2021-04-08 08:00:00
# 1347620     REGULAR  11289337  10471689 2021-04-08 06:41:49
# 1347619     REGULAR  11289337  10471686 2021-04-08 06:40:30
# 1347618     REGULAR   1871552     39768 2021-04-08 04:00:00
# 1347617     REGULAR   1871551     39764 2021-04-08 00:00:00

# %% [markdown]
# Each combination of C/A, UNIT, SCP, and STATION represents a unique turnstile.  Let's take a look at
# one specific turnstile on a specific date to see what each row of the dataframe represents.

# %%
df_mta[(df_mta["C/A"] == "A002") & 
(df_mta["UNIT"] == "R051") & 
(df_mta["SCP"] == "02-00-00") & 
(df_mta["STATION"] == "59 ST") &
(df_mta["DATE"] == "01/01/2021")]
# Out:
#           C/A  UNIT       SCP STATION LINENAME        DATE      TIME     DESC  \
# 2029334  A002  R051  02-00-00   59 ST  NQR456W  01/01/2021  23:00:00  REGULAR
# 2029333  A002  R051  02-00-00   59 ST  NQR456W  01/01/2021  19:00:00  REGULAR
# 2029332  A002  R051  02-00-00   59 ST  NQR456W  01/01/2021  15:00:00  REGULAR
# 2029331  A002  R051  02-00-00   59 ST  NQR456W  01/01/2021  11:00:00  REGULAR
# 2029330  A002  R051  02-00-00   59 ST  NQR456W  01/01/2021  07:00:00  REGULAR
# 2029329  A002  R051  02-00-00   59 ST  NQR456W  01/01/2021  03:00:00  REGULAR
#
#          ENTRIES    EXITS           DATE_TIME
# 2029334  7511647  2558865 2021-01-01 23:00:00
# 2029333  7511620  2558857 2021-01-01 19:00:00
# 2029332  7511495  2558831 2021-01-01 15:00:00
# 2029331  7511461  2558813 2021-01-01 11:00:00
# 2029330  7511451  2558789 2021-01-01 07:00:00
# 2029329  7511448  2558786 2021-01-01 03:00:00

# %%
turnstiles_daily = (df_mta
                        .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE"],as_index=False)
                        .ENTRIES.first())

# %%
turnstiles_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES
# 0  A002  R051  02-00-00   59 ST  01/01/2021  7511647
# 1  A002  R051  02-00-00   59 ST  01/02/2021  7511996
# 2  A002  R051  02-00-00   59 ST  01/03/2021  7512214
# 3  A002  R051  02-00-00   59 ST  01/04/2021  7512754
# 4  A002  R051  02-00-00   59 ST  01/05/2021  7513300

# %%
# import datetime

# %% [markdown]
# Entries column contains the cumulative entries on each day, this will be used to calculate the daily entries
# - daily entries = the new number of entries gained each day, the data to be grouped by turnstile

# %%
turnstiles_daily[["PREV_DATE", "PREV_ENTRIES"]] = (turnstiles_daily
                                                       .groupby(["C/A", "UNIT", "SCP", "STATION"])[["DATE", "ENTRIES"]]
                                                       .apply(lambda grp: grp.shift(1)))

# turnstiles_daily[["PREV_DATE", "PREV_ENTRIES"]] = (turnstiles_daily
#                                                        .groupby(["C/A", "UNIT", "SCP", "STATION"])[["DATE", "ENTRIES"]]
#                                                        .shift(1))

# %%
turnstiles_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  PREV_ENTRIES
# 0  A002  R051  02-00-00   59 ST  01/01/2021  7511647         NaN           NaN
# 1  A002  R051  02-00-00   59 ST  01/02/2021  7511996  01/01/2021     7511647.0
# 2  A002  R051  02-00-00   59 ST  01/03/2021  7512214  01/02/2021     7511996.0
# 3  A002  R051  02-00-00   59 ST  01/04/2021  7512754  01/03/2021     7512214.0
# 4  A002  R051  02-00-00   59 ST  01/05/2021  7513300  01/04/2021     7512754.0

# %%
turnstiles_daily.tail()
# Out:
#            C/A  UNIT       SCP        STATION        DATE  ENTRIES  \
# 1227938  TRAM2  R469  00-05-01  RIT-ROOSEVELT  08/30/2021     5554
# 1227939  TRAM2  R469  00-05-01  RIT-ROOSEVELT  08/31/2021     5554
# 1227940  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/01/2021     5554
# 1227941  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/02/2021     5554
# 1227942  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/03/2021     5554
#
#           PREV_DATE  PREV_ENTRIES
# 1227938  08/29/2021        5554.0
# 1227939  08/30/2021        5554.0
# 1227940  08/31/2021        5554.0
# 1227941  09/01/2021        5554.0
# 1227942  09/02/2021        5554.0

# %%
# Drop the rows for the earliest date in the df
turnstiles_daily.dropna(subset=["PREV_DATE"], axis=0, inplace=True)

# %%
(turnstiles_daily["ENTRIES"] - turnstiles_daily["PREV_ENTRIES"]).describe()
# Out:
# count    1.222860e+06
# mean    -4.682749e+03
# std      4.516161e+06
# min     -1.604323e+09
# 25%      6.200000e+01
# 50%      2.230000e+02
# 75%      4.600000e+02
# max      2.139011e+09
# dtype: float64

# %% [markdown]
# - two anomalies, extreamly large values and negative values

# %%
# How many rows are backwards
turnstiles_daily[turnstiles_daily["ENTRIES"] < turnstiles_daily["PREV_ENTRIES"]].shape
# Out:
# (11357, 8)

# %%
turnstiles_daily[turnstiles_daily["ENTRIES"] < turnstiles_daily["PREV_ENTRIES"]].head()
# Out:
#        C/A  UNIT       SCP     STATION        DATE    ENTRIES   PREV_DATE  \
# 1064  A002  R051  02-03-02       59 ST  03/22/2021        238  03/21/2021
# 9593  A011  R080  01-03-00  57 ST-7 AV  01/02/2021  885629436  01/01/2021
# 9594  A011  R080  01-03-00  57 ST-7 AV  01/03/2021  885629336  01/02/2021
# 9595  A011  R080  01-03-00  57 ST-7 AV  01/04/2021  885629148  01/03/2021
# 9596  A011  R080  01-03-00  57 ST-7 AV  01/05/2021  885628924  01/04/2021
#
#       PREV_ENTRIES
# 1064     6641395.0
# 9593   885629558.0
# 9594   885629436.0
# 9595   885629336.0
# 9596   885629148.0

# %%
# What's the deal with counter being in reverse
mask = ((df_mta["C/A"] == "A011") & 
(df_mta["UNIT"] == "R080") & 
(df_mta["SCP"] == "01-03-00") & 
(df_mta["STATION"] == "57 ST-7 AV") &
(df_mta["DATE_TIME"].dt.date == datetime.date(2021, 1, 2)))

# %%
# It's actually a good idea to plot this, if you could
df_mta[mask].sort_values('DATE_TIME')[['DATE', 'TIME', 'ENTRIES', 'EXITS']]
# Out:
#                DATE      TIME    ENTRIES      EXITS
# 1971889  01/02/2021  03:00:00  885629550  489699496
# 1971890  01/02/2021  07:00:00  885629549  489699476
# 1971891  01/02/2021  11:00:00  885629539  489699340
# 1971892  01/02/2021  15:00:00  885629523  489699138
# 1971893  01/02/2021  19:00:00  885629468  489698994
# 1971894  01/02/2021  23:00:00  885629436  489698939

# %%
# Let's see how many stations have this problem
(turnstiles_daily[turnstiles_daily["ENTRIES"] < turnstiles_daily["PREV_ENTRIES"]]
    .groupby(["C/A", "UNIT", "SCP", "STATION"])
    .size())
# Out:
# C/A    UNIT  SCP       STATION
# A002   R051  02-03-02  59 ST                1
# A011   R080  01-03-00  57 ST-7 AV         245
#              01-03-01  57 ST-7 AV           1
#              01-03-03  57 ST-7 AV           1
#              01-03-04  57 ST-7 AV           1
#                                          ...
# R646   R110  01-00-02  FLATBUSH AV-B.C      1
# R730   R431  00-00-04  EASTCHSTER/DYRE    244
# S101   R070  00-00-02  ST. GEORGE           1
#              00-00-04  ST. GEORGE           1
# TRAM2  R469  00-05-00  RIT-ROOSEVELT        1
# Length: 419, dtype: int64

# %%
def get_daily_counts(row, max_counter):
    counter = row["ENTRIES"] - row["PREV_ENTRIES"]
    
    if counter < 0:
        counter = -counter  # adjust for "reverse" counter
        
    if counter > max_counter:
        # Maybe counter was reset, so it may make sense to take the minimum
        print(f'entries: {row["ENTRIES"]} <-- {row["PREV_ENTRIES"]}')
        counter = min(row["ENTRIES"], row["PREV_ENTRIES"])
        
    if counter > max_counter:
        # If we still get a counter that is too big, set to zero
        return 0
    
    return counter

turnstiles_daily["DAILY_ENTRIES"] = turnstiles_daily.apply(get_daily_counts, axis=1, max_counter=1000000)
# Out:
# entries: 238 <-- 6641395.0
# entries: 52806 <-- 17116894.0
# entries: 3082 <-- 1390173.0
# entries: 18 <-- 4340953.0
# entries: 117 <-- 11715665.0
# entries: 198 <-- 5102094.0
# entries: 738 <-- 18398229.0
# entries: 327680 <-- 185586773.0
# entries: 169 <-- 2172444.0
# entries: 14 <-- 1028362.0
# entries: 25 <-- 1400020.0
# entries: 127 <-- 1657032.0
# entries: 327680 <-- 756269765.0
# entries: 262152 <-- 553649999.0
# entries: 262152 <-- 229572623.0
# entries: 353 <-- 8049630.0
# entries: 0 <-- 5309746.0
# entries: 80 <-- 1640812.0
# entries: 327834 <-- 2642486.0
# entries: 101 <-- 2651127.0
# entries: 104 <-- 17275602.0
# entries: 16796392 <-- 123975.0
# entries: 453044031 <-- 1779426.0
# entries: 167790157 <-- 702266.0
# entries: 262272 <-- 2255518.0
# entries: 393225 <-- 7714275.0
# entries: 57 <-- 2028804.0
# entries: 48 <-- 8724126.0
# entries: 2147432315 <-- 8421808.0
# entries: 16712028 <-- 6294957.0
# entries: 177 <-- 16712669.0
# entries: 262144 <-- 33554713.0
# entries: 394 <-- 2773389.0
# entries: 24 <-- 2627860.0
# entries: 106 <-- 67960951.0
# entries: 232 <-- 4735529.0
# entries: 153 <-- 1604971.0
# entries: 5946 <-- 4298704.0
# entries: 0 <-- 117440512.0
# entries: 147 <-- 11567738.0
# entries: 135 <-- 8882903.0
# entries: 1950 <-- 13809288.0
# entries: 54 <-- 7903750.0
# entries: 113 <-- 4454729.0
# entries: 158 <-- 7643335.0
# entries: 2293788 <-- 4259642.0
# entries: 471 <-- 1377273.0
# entries: 248 <-- 827160459.0
# entries: 327975 <-- 7577027.0
# entries: 0 <-- 67108864.0
# entries: 47 <-- 2514854.0
# entries: 1376376 <-- 8181460.0
# entries: 420 <-- 4343900.0
# entries: 217 <-- 4780275.0
# entries: 262297 <-- 1566066.0
# entries: 1534984195 <-- 0.0
# entries: 4 <-- 1534984197.0
# entries: 67109632 <-- 14.0
# entries: 327682 <-- 67109640.0
# entries: 67109632 <-- 1.0
# entries: 15 <-- 67109632.0
# entries: 12517611 <-- 82.0
# entries: 36 <-- 1198448.0
# entries: 23157312 <-- 1627480738.0
# entries: 46 <-- 5405351.0
# entries: 687970551 <-- 19471253.0
# entries: 200 <-- 705357551.0
# entries: 35 <-- 10195434.0
# entries: 702 <-- 3651815.0
# entries: 697 <-- 13204039.0
# entries: 1076 <-- 7489966.0
# entries: 16777220 <-- 1037157.0
# entries: 463 <-- 6101664.0
# entries: 162 <-- 1110928.0
# entries: 6 <-- 16034831.0
# entries: 327 <-- 2524852.0
# entries: 262150 <-- 2393328.0
# entries: 262152 <-- 67112607.0
# entries: 67436550 <-- 375578.0
# entries: 143 <-- 4070964.0
# entries: 5 <-- 58304715.0
# entries: 386 <-- 6213955.0
# entries: 191 <-- 2811568.0
# entries: 37 <-- 1950780.0
# entries: 647 <-- 239666917.0
# entries: 0 <-- 2042881.0
# entries: 443 <-- 15689395.0
# entries: 262144 <-- 537268042.0
# entries: 262185 <-- 67617764.0
# entries: 528 <-- 2341721.0
# entries: 494 <-- 1930690.0
# entries: 33030166 <-- 42.0
# entries: 2 <-- 33030303.0
# entries: 8 <-- 1255797.0
# entries: 165 <-- 11883611.0
# entries: 44 <-- 9855012.0
# entries: 262296 <-- 8864207.0
# entries: 95 <-- 5198958.0
# entries: 126 <-- 3102523.0
# entries: 15439231 <-- 6237114.0
# entries: 338 <-- 15440422.0
# entries: 436 <-- 1721769.0
# entries: 126 <-- 1965830.0
# entries: 79 <-- 1663686.0
# entries: 72 <-- 2101534.0
# entries: 262145 <-- 67109778.0
# entries: 15 <-- 1571402.0
# entries: 50362839 <-- 251769.0
# entries: 85 <-- 4001974.0
# entries: 77 <-- 2320032.0
# entries: 114 <-- 1953264.0
# entries: 169 <-- 4788322.0
# entries: 36 <-- 1380657.0
# entries: 393362 <-- 104110933.0
# entries: 315 <-- 2844675.0
# entries: 175 <-- 315605508.0
# entries: 82 <-- 6249985.0
# entries: 852524 <-- 2830560.0
# entries: 688 <-- 141769497.0
# entries: 118 <-- 909043641.0
# entries: 66470 <-- 17650908.0
# entries: 357 <-- 4470823.0
# entries: 70 <-- 30154514.0
# entries: 1040213826 <-- 4086923.0
# entries: 197214 <-- 1890967.0
# entries: 151200964 <-- 50928236.0
# entries: 196847 <-- 3277233.0
# entries: 87 <-- 303654987.0
# entries: 716 <-- 3145979.0
# entries: 738431481 <-- 53263405.0
# entries: 53237519 <-- 738434610.0
# entries: 73220297 <-- 1560551488.0
# entries: 35 <-- 10737302.0
# entries: 146668889 <-- 1123536132.0
# entries: 1191142711 <-- 12133750.0
# entries: 3539010 <-- 51735353.0
# entries: 536886506 <-- 2125787.0
# entries: 124 <-- 2030205.0
# entries: 145 <-- 37879542.0
# entries: 112 <-- 7682427.0
# entries: 1441950 <-- 12919101.0
# entries: 13943099 <-- 8899046.0
# entries: 62 <-- 4183413.0
# entries: 499 <-- 1278035.0
# entries: 113 <-- 1684097.0
# entries: 632 <-- 4266134.0
# entries: 119 <-- 1208346.0
# entries: 142 <-- 1653213.0
# entries: 395 <-- 11851520.0
# entries: 91 <-- 1925928.0
# entries: 327683 <-- 50346231.0
# entries: 104 <-- 11667763.0
# entries: 577 <-- 11839228.0
# entries: 41 <-- 6481415.0
# entries: 92 <-- 1383110115.0
# entries: 14455033 <-- 262149.0
# entries: 0 <-- 14455033.0

# %%
turnstiles_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  01/02/2021  7511996  01/01/2021
# 2  A002  R051  02-00-00   59 ST  01/03/2021  7512214  01/02/2021
# 3  A002  R051  02-00-00   59 ST  01/04/2021  7512754  01/03/2021
# 4  A002  R051  02-00-00   59 ST  01/05/2021  7513300  01/04/2021
# 5  A002  R051  02-00-00   59 ST  01/06/2021  7513790  01/05/2021
#
#    PREV_ENTRIES  DAILY_ENTRIES
# 1     7511647.0          349.0
# 2     7511996.0          218.0
# 3     7512214.0          540.0
# 4     7512754.0          546.0
# 5     7513300.0          490.0

# %%
turnstiles_daily.DAILY_ENTRIES.describe()
# Out:
# count    1.222860e+06
# mean     3.920843e+02
# std      5.728246e+03
# min      0.000000e+00
# 25%      6.800000e+01
# 50%      2.280000e+02
# 75%      4.660000e+02
# max      9.934550e+05
# Name: DAILY_ENTRIES, dtype: float64

# %%
turnstiles_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1222860 entries, 1 to 1227942
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   C/A            1222860 non-null  object
#  1   UNIT           1222860 non-null  object
#  2   SCP            1222860 non-null  object
#  3   STATION        1222860 non-null  object
#  4   DATE           1222860 non-null  object
#  5   ENTRIES        1222860 non-null  int64
#  6   PREV_DATE      1222860 non-null  object
#  7   PREV_ENTRIES   1222860 non-null  float64
#  8   DAILY_ENTRIES  1222860 non-null  float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 93.3+ MB

# %%
turnstiles_daily[turnstiles_daily.DAILY_ENTRIES >= 3000]
# Out:
#            C/A  UNIT       SCP        STATION        DATE   ENTRIES  \
# 5202      A007  R079  01-05-01     5 AV/59 ST  02/08/2021    262144
# 9865      A011  R080  01-03-01     57 ST-7 AV  01/28/2021     52806
# 10447     A011  R080  01-03-03     57 ST-7 AV  04/28/2021        59
# 10706     A011  R080  01-03-04     57 ST-7 AV  05/11/2021      3082
# 13177     A013  R081  01-06-01          49 ST  05/22/2021        29
# ...        ...   ...       ...            ...         ...       ...
# 1218363   S101  R070  00-00-02     ST. GEORGE  08/31/2021   1396283
# 1218366   S101  R070  00-00-02     ST. GEORGE  09/03/2021   1213616
# 1218703   S101  R070  00-00-04     ST. GEORGE  04/01/2021        25
# 1227592  TRAM2  R469  00-05-00  RIT-ROOSEVELT  05/22/2021    262149
# 1227594  TRAM2  R469  00-05-00  RIT-ROOSEVELT  05/24/2021  14455033
#
#           PREV_DATE  PREV_ENTRIES  DAILY_ENTRIES
# 5202     02/06/2021           0.0       262144.0
# 9865     01/27/2021    17116894.0        52806.0
# 10447    04/27/2021      154688.0       154629.0
# 10706    05/10/2021     1390173.0         3082.0
# 13177    05/21/2021      479839.0       479810.0
# ...             ...           ...            ...
# 1218363  08/30/2021     1213236.0       183047.0
# 1218366  09/02/2021     1396473.0       182857.0
# 1218703  03/31/2021      980934.0       980909.0
# 1227592  05/21/2021        3258.0       258891.0
# 1227594  05/23/2021      262149.0       262149.0
#
# [497 rows x 9 columns]

# %%
turnstiles_daily_no_outliers = turnstiles_daily[turnstiles_daily.DAILY_ENTRIES <= 3000]

# %%
turnstiles_daily_no_outliers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1222363 entries, 1 to 1227942
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   C/A            1222363 non-null  object
#  1   UNIT           1222363 non-null  object
#  2   SCP            1222363 non-null  object
#  3   STATION        1222363 non-null  object
#  4   DATE           1222363 non-null  object
#  5   ENTRIES        1222363 non-null  int64
#  6   PREV_DATE      1222363 non-null  object
#  7   PREV_ENTRIES   1222363 non-null  float64
#  8   DAILY_ENTRIES  1222363 non-null  float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 93.3+ MB

# %%
turnstiles_daily_no_outliers.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  01/02/2021  7511996  01/01/2021
# 2  A002  R051  02-00-00   59 ST  01/03/2021  7512214  01/02/2021
# 3  A002  R051  02-00-00   59 ST  01/04/2021  7512754  01/03/2021
# 4  A002  R051  02-00-00   59 ST  01/05/2021  7513300  01/04/2021
# 5  A002  R051  02-00-00   59 ST  01/06/2021  7513790  01/05/2021
#
#    PREV_ENTRIES  DAILY_ENTRIES
# 1     7511647.0          349.0
# 2     7511996.0          218.0
# 3     7512214.0          540.0
# 4     7512754.0          546.0
# 5     7513300.0          490.0

# %%
pd.options.display.float_format = '{:.0f}'.format

# %%
turnstiles_daily_no_outliers.describe()
# Out:
#          ENTRIES  PREV_ENTRIES  DAILY_ENTRIES
# count    1222363       1222363        1222363
# mean    41799665      41802291            321
# std    218264039     218268080            335
# min            0             0              0
# 25%       216119        216044             68
# 50%      1432000       1432468            228
# 75%      6069886       6070584            466
# max   2147432315    2147432315           2999

# %% [markdown]
# STOPPED HERE

# %%
ca_unit_station_daily = turnstiles_daily_no_outliers.groupby(["C/A", "UNIT", "STATION", "DATE"])[['DAILY_ENTRIES']].sum().reset_index()
ca_unit_station_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  DAILY_ENTRIES
# 0  A002  R051  02-00-00   59 ST  01/02/2021            349
# 1  A002  R051  02-00-00   59 ST  01/03/2021            218
# 2  A002  R051  02-00-00   59 ST  01/04/2021            540
# 3  A002  R051  02-00-00   59 ST  01/05/2021            546
# 4  A002  R051  02-00-00   59 ST  01/06/2021            490

# %%
station_daily = turnstiles_daily_no_outliers.groupby(["STATION", "DATE"])[['DAILY_ENTRIES']].sum().reset_index()
station_daily.head(200)
# Out:
#     STATION        DATE  DAILY_ENTRIES
# 0      1 AV  01/02/2021           3673
# 1      1 AV  01/03/2021           2547
# 2      1 AV  01/04/2021           5303
# 3      1 AV  01/05/2021           5468
# 4      1 AV  01/06/2021           5603
# ..      ...         ...            ...
# 195    1 AV  07/16/2021           8466
# 196    1 AV  07/17/2021           6954
# 197    1 AV  07/18/2021           6028
# 198    1 AV  07/19/2021           7373
# 199    1 AV  07/20/2021           7668
#
# [200 rows x 3 columns]

# %%
ca_unit_station_daily = turnstiles_daily_no_outliers.groupby(["STATION"])[['DAILY_ENTRIES']].sum().reset_index()
ca_unit_station_daily.head()
# Out:
#          STATION  DAILY_ENTRIES
# 0           1 AV        1587344
# 1         103 ST        2331753
# 2  103 ST-CORONA        2322242
# 3         104 ST         407621
# 4         110 ST         894804

# %%
station_totals = ca_unit_station_daily.sort_values(by='DAILY_ENTRIES', ascending=False).head(20)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_formats = ['svg']  # or retina
# %matplotlib inline

sns.set(context='notebook', 
    style='whitegrid', 
    font_scale=1.1)

# %%
plt.hist(station_totals['DAILY_ENTRIES']);
plt.xlabel('Daily Entries')
plt.ylabel('# of Stations');

# %%
plt.bar(x=station_totals['STATION'][:20], height=station_totals['DAILY_ENTRIES'][:20])
plt.xticks(rotation=90);
plt.ylabel("Cumulative Daily Entries");
plt.savefig("entries_per_station.png");
